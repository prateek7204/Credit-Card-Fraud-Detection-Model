# %% [markdown]
# # CREDIT CARD FRAUD DETECTION USING LOGISTIC REGRESSION

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\Data related files\Credit Card Fraud Dataset\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
real = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
real.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
real.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#as the data is imbalanced as we can see that the real cases are over 2 lakhs and the fraudulent cases are only 492 so we are
#going to take any random 492 

real_sample = real.sample(n=492) #random sampling

# %%
#concatinating two datasets 
new = pd.concat([real_sample, fraud], axis = 0) #values will be added row wise

# %%
new.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 81679    59042.0  1.251956 -0.464915 -0.129615 -0.513229 -0.664776 -1.055139
# 110183   71714.0 -0.744164 -0.689037  2.095510 -2.405102 -1.436101 -0.025736
# 68079    52824.0  1.145852 -0.182185  0.106589  1.089140  0.100170  0.949559
# 37497    38982.0 -1.321083  0.315447  1.732102 -0.865954 -1.635985  0.173292
# 154984  103913.0  0.831690 -3.008023 -1.325752 -0.410791 -0.765436  1.547661
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 81679   0.074113 -0.347746 -1.328495  ... -0.317431 -0.491970  0.005741
# 110183  0.011726  0.041713 -2.358284  ...  0.098789  0.400263  0.055294
# 68079  -0.374217  0.387070  0.629015  ... -0.067305 -0.077955 -0.244110
# 37497   0.467223  0.499969  0.403598  ...  0.082005  0.207002  0.160614
# 154984 -0.476201  0.231219  1.179515  ...  0.102408 -0.726164 -0.113552
#
# ...

# %%
new['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      93990.833333  0.081450 -0.005262 -0.033097  0.016636 -0.006039
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.003762 -0.004778  0.012573 -0.022016  ... -0.002680  0.047755
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.037281  0.019643 -0.008363  0.013364 -0.005331  0.013555  0.002885
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       92.258374
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X = new.drop(columns = 'Class', axis = 1)
Y = new['Class']

# %%
X.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 81679    59042.0  1.251956 -0.464915 -0.129615 -0.513229 -0.664776 -1.055139
# 110183   71714.0 -0.744164 -0.689037  2.095510 -2.405102 -1.436101 -0.025736
# 68079    52824.0  1.145852 -0.182185  0.106589  1.089140  0.100170  0.949559
# 37497    38982.0 -1.321083  0.315447  1.732102 -0.865954 -1.635985  0.173292
# 154984  103913.0  0.831690 -3.008023 -1.325752 -0.410791 -0.765436  1.547661
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 81679   0.074113 -0.347746 -1.328495  ... -0.363074 -0.317431 -0.491970
# 110183  0.011726  0.041713 -2.358284  ... -0.030476  0.098789  0.400263
# 68079  -0.374217  0.387070  0.629015  ... -0.225452 -0.067305 -0.077955
# 37497   0.467223  0.499969  0.403598  ... -0.229844  0.082005  0.207002
# 154984 -0.476201  0.231219  1.179515  ...  1.091893  0.102408 -0.726164
#
# ...

# %%
Y.tail()
# Out:
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, dtype: int64

# %%
#splitting the data into training and testing 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2 , stratify = Y, random_state = 2)

# %%
X.shape, X_train.shape, X_test.shape
# Out:
# ((984, 30), (787, 30), (197, 30))

# %%
#model training 
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_accuracy = accuracy_score(X_train_prediction, y_train)

# %%
print('The Accuracy of the Training Model is : ', training_accuracy)
# Out:
# The Accuracy of the Training Model is :  0.9250317662007624

# %%
X_test_prediction = model.predict(X_test)
testing_accuracy = accuracy_score(X_test_prediction, y_test)

# %%
print('The Accuracy of the Testing Model is : ', testing_accuracy)
# Out:
# The Accuracy of the Testing Model is :  0.8984771573604061
